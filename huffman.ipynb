# %%
#coding: utf-8
from PIL import Image
#Using python's PIL module to process images 
 
class node: #Node's class
         #Define node construction method
    def __init__(self,right=None,left=None, parent=None, weight=0, code=None):
        self.left = left 
        self.right = right 
        self.parent = parent 
        self.weight = weight #weight
        self.code = code #Node value
        
 #Define function, convert the color image to a gray image, at this time each pixel of the image can be represented by a separate pixel value
def picture_convert(filename,newfilename): 
    picture = Image.open(filename)
    picture = picture.convert('L')#Convert bmp picture to gray value picture
    picture. save(newfilename)#Save grayscale image
    return picture
 
 #Define function, count the number of times each pixel appears
def pixel_number_caculate(list):
    pixel_number={}
    for i in list:
        if i not in pixel_number. keys():
                         pixel_number[i]=1 #If the pixel is not in the character frequency dictionary, add it directly
        else:
                         pixel_number[i] += 1 #If it exists in the character frequency string dictionary, add one to the corresponding value 
    return pixel_number
 
 #Construct a node, give its value and corresponding weight respectively 
def node_construct(pixel_number): 
    node_list =[]
    for i in range(len(pixel_number)):
        node_list.append(node(weight=pixel_number[i][1],code=str(pixel_number[i][0])))
    return node_list
 
 #Construct a node, give its value and corresponding weight respectively 
def node_construct(pixel_number): 
    node_list =[]
    for i in range(len(pixel_number)):
        node_list.append(node(weight=pixel_number[i][1],code=str(pixel_number[i][0])))
    return node_list
 
 #According to the list of leaf nodes, generate the corresponding Huffman coding tree
def tree_construct(listnode):
    listnode = sorted(listnode,key=lambda node:node.weight) 
    while len(listnode) != 1:
                 # Each time the two pixel points of the weighted value are merged
        low_node0,low_node1 = listnode[0], listnode[1]
        new_change_node = node()
        new_change_node.weight = low_node0.weight + low_node1.weight
        new_change_node.left = low_node0
        new_change_node.right = low_node1
        low_node0.parent = new_change_node
        low_node1.parent = new_change_node
        listnode.remove(low_node0)
        listnode.remove(low_node1)
        listnode.append(new_change_node)
        listnode = sorted(listnode, key=lambda node:node.weight) 
    return listnode
 #The main function of Huffman coding, which completes the coding of pixels by calling other functions
def Huffman_Coding(picture):
         #Get the width and height of the picture
    width = picture.size[0]
    height = picture.size[1]
    im = picture.load()
    print ("Grayscale image width is"+str(width)+" pixel")
    print ("Grayscale image height is"+str(height)+" pixel")
 
         #Save the pixels in Jist, the original two-dimensional matrix becomes a one-dimensional array 
    list =[]
    for i in range(width):
        for j in range(height): 
            list.append(im[i,j])
         #Count the number of times of each pixel, and sort according to the number of occurrences from small to large 
    pixel_number = pixel_number_caculate(list)
    pixel_number = sorted(pixel_number.items(),key=lambda item:item[1])
           
         #Construct the node list according to the value of the pixel and the number of occurrences 
    node_list = node_construct(pixel_number)
         # Construct a Huffman tree, save the head node
    head = tree_construct(node_list)[0]
           
         #Construction code table
    coding_table = {}
    for e in node_list:
        new_change_node = e
        coding_table.setdefault(e.code,"")
        while new_change_node !=head:
            if new_change_node.parent.left == new_change_node: 
                coding_table[e.code] = "1" + coding_table[e.code] 
            else:
                coding_table[e.code] = "0" + coding_table[e.code] 
            new_change_node = new_change_node. parent
         #Output the gray value and code of each image accumulation point
    for key in coding_table.keys():
                 print ("source pixel" + key + "code strength after encoding:" + coding_table[key])
 
 
         #Output encoding table
    print ("The coding table is:", coding_table)
 
         #Convert the encoding result of the image into a string and save it in txt 
    coding_result = ''
    for i in range(width):
        for j in range(height):
            for key,values in coding_table.items(): 
                if str(im[i,j]) == key:
                    coding_result = coding_result+values 
    file = open('coding_result.txt','w') 
    file.write(coding_result)
 
 #Restore the original bmp image, traverse the result of Huffman encoding, for each traversed character is in the codeword list 
# Search in #, if not found, add the next character, continue to search, repeat this step until you find it in the code word list 
 #Go to the pixel corresponding to the codeword, and put the pixel value corresponding to the codeword into the pixel list.
def Decoding(width,height,coding_table,coding_result): 
    code_read_now=''#The currently read code 
    new_pixel =[] 
    i = 0
    while (i != coding_result.__len__()):
                 #Read one later each time
        code_read_now = code_read_now + coding_result[i]
        for key in coding_table.keys():
                         #If the currently read code exists in the code table 
            if code_read_now == coding_table[key]: 
                new_pixel. append(key) 
                code_read_now = ' '
                break
        i +=1
         #Construct a new image
    decode_image = Image.new( 'L' ,(width,height)) 
    k = 0 
         # 
    for i in range(width):
        for j in range(height):
            decode_image.putpixel((i,j),(int(new_pixel[k]))) 
        k+=1
    decode_image.save('decode.bmp') 
    print("Decoding has been completed: the picture is stored as decode.bmp")

# %%
picture = picture_convert('l.ppm','new.bmp')
Huffman_Coding(picture)
# Out:
# Grayscale image width is320pixel
# Grayscale image height is240pixel
# source pixel9code strength after encoding:00011111111
# source pixel204code strength after encoding:00011111110
# source pixel212code strength after encoding:0100000101
# source pixel23code strength after encoding:0100000100
# source pixel189code strength after encoding:0011000001
# source pixel190code strength after encoding:0011000000
# source pixel133code strength after encoding:0001111110
# source pixel142code strength after encoding:0001001011
# source pixel159code strength after encoding:0001001010
# source pixel194code strength after encoding:0000100111
# source pixel151code strength after encoding:0000100110
# source pixel132code strength after encoding:0000010001
# source pixel167code strength after encoding:0000010000
# source pixel146code strength after encoding:111111111
# source pixel176code strength after encoding:111111110
# source pixel203code strength after encoding:111001101
# source pixel80code strength after encoding:111001100
# source pixel186code strength after encoding:011110001
# source pixel55code strength after encoding:011110000
# source pixel75code strength after encoding:011001001
# source pixel86code strength after encoding:011001000
# source pixel57code strength after encoding:010111001
# source pixel162code strength after encoding:010111000
# source pixel200code strength after encoding:010010001
# source pixel137code strength after encoding:010010000
# source pixel180code strength after encoding:010000011
# source pixel168code strength after encoding:001111001
# source pixel163code strength after encoding:001111000
# source pixel185code strength after encoding:001101111
# source pixel27code strength after encoding:001101110
# source pixel26code strength after encoding:001100001
# source pixel181code strength after encoding:001010011
# source pixel105code strength after encoding:001010010
# source pixel139code strength after encoding:000111110
# source pixel150code strength after encoding:000110111
# source pixel29code strength after encoding:000110110
# source pixel129code strength after encoding:000110101
# source pixel127code strength after encoding:000110100
# source pixel116code strength after encoding:000100100
# source pixel28code strength after encoding:000010111
# source pixel197code strength after encoding:000010110
# source pixel188code strength after encoding:000010010
# source pixel123code strength after encoding:000001101
# source pixel149code strength after encoding:000001100
# source pixel54code strength after encoding:000001001
# source pixel71code strength after encoding:11111110
# source pixel158code strength after encoding:11110101
# source pixel2code strength after encoding:11110100
# source pixel58code strength after encoding:11100111
# source pixel92code strength after encoding:11001101
# source pixel144code strength after encoding:11001100
# source pixel93code strength after encoding:01111111
# source pixel131code strength after encoding:01111110
# source pixel84code strength after encoding:01111001
# source pixel136code strength after encoding:01101001
# source pixel68code strength after encoding:01101000
# source pixel60code strength after encoding:01100101
# source pixel143code strength after encoding:01011101
# source pixel39code strength after encoding:01001001
# source pixel156code strength after encoding:01000101
# source pixel160code strength after encoding:01000100
# source pixel61code strength after encoding:01000000
# source pixel184code strength after encoding:00111101
# source pixel48code strength after encoding:00111001
# source pixel42code strength after encoding:00111000
# source pixel78code strength after encoding:00110110
# source pixel178code strength after encoding:00110001
# source pixel64code strength after encoding:00101000
# source pixel135code strength after encoding:00100001
# source pixel83code strength after encoding:00100000
# source pixel191code strength after encoding:00011110
# source pixel50code strength after encoding:00011001
# source pixel108code strength after encoding:00011000
# source pixel153code strength after encoding:00010101
# source pixel96code strength after encoding:00010100
# source pixel65code strength after encoding:00010011
# source pixel145code strength after encoding:00010001
# source pixel63code strength after encoding:00010000
# source pixel66code strength after encoding:00001010
# source pixel128code strength after encoding:00001000
# source pixel121code strength after encoding:00000111
# source pixel67code strength after encoding:00000101
# source pixel120code strength after encoding:00000001
# source pixel140code strength after encoding:00000000
# source pixel107code strength after encoding:1111110
# source pixel98code strength after encoding:1111101
# source pixel87code strength after encoding:1111100
# source pixel134code strength after encoding:1111011
# source pixel90code strength after encoding:1111001
# source pixel56code strength after encoding:1111000
# source pixel59code strength after encoding:1110111
# source pixel77code strength after encoding:1110110
# source pixel95code strength after encoding:1110010
# source pixel74code strength after encoding:1101011
# source pixel165code strength after encoding:1101010
# source pixel122code strength after encoding:1100111
# source pixel130code strength after encoding:1100101
# source pixel174code strength after encoding:1100100
# source pixel126code strength after encoding:0111110
# source pixel91code strength after encoding:0111101
# source pixel117code strength after encoding:0111001
# source pixel76code strength after encoding:0111000
# source pixel44code strength after encoding:0110101
# source pixel89code strength after encoding:0110011
# source pixel40code strength after encoding:0101111
# source pixel99code strength after encoding:0101001
# source pixel138code strength after encoding:0101000
# source pixel35code strength after encoding:0100101
# source pixel114code strength after encoding:0100011
# source pixel41code strength after encoding:0100001
# source pixel124code strength after encoding:0011111
# source pixel69code strength after encoding:0011101
# source pixel85code strength after encoding:0011010
# source pixel102code strength after encoding:0011001
# source pixel101code strength after encoding:0010111
# source pixel170code strength after encoding:0010110
# source pixel106code strength after encoding:0010101
# source pixel112code strength after encoding:0010011
# source pixel111code strength after encoding:0010010
# source pixel52code strength after encoding:0010001
# source pixel104code strength after encoding:0001110
# source pixel100code strength after encoding:0001011
# source pixel43code strength after encoding:0000001
# source pixel32code strength after encoding:111010
# source pixel109code strength after encoding:111000
# source pixel113code strength after encoding:110111
# source pixel72code strength after encoding:110110
# source pixel94code strength after encoding:110100
# source pixel36code strength after encoding:110001
# source pixel119code strength after encoding:110000
# source pixel34code strength after encoding:011101
# source pixel37code strength after encoding:011011
# source pixel115code strength after encoding:011000
# source pixel47code strength after encoding:010110
# source pixel81code strength after encoding:010101
# source pixel1code strength after encoding:010011
# source pixel38code strength after encoding:000011
# source pixel0code strength after encoding:10
# The coding table is: {'9': '00011111111', '204': '00011111110', '212': '0100000101', '23': '0100000100', '189': '0011000001', '190': '0011000000', '133': '0001111110', '142': '0001001011', '159': '0001001010', '194': '0000100111', '151': '0000100110', '132': '0000010001', '167': '0000010000', '146': '111111111', '176': '111111110', '203': '111001101', '80': '111001100', '186': '011110001', '55': '011110000', '75': '011001001', '86': '011001000', '57': '010111001', '162': '010111000', '200': '010010001', '137': '010010000', '180': '010000011', '168': '001111001', '163': '001111000', '185': '001101111', '27': '001101110', '26': '001100001', '181': '001010011', '105': '001010010', '139': '000111110', '150': '000110111', '29': '000110110', '129': '000110101', '127': '000110100', '116': '000100100', '28': '000010111', '197': '000010110', '188': '000010010', '123': '000001101', '149': '000001100', '54': '000001001', '71': '11111110', '158': '11110101', '2': '11110100', '58': '11100111', '92': '11001101', '144': '11001100', '93': '01111111', '131': '01111110', '84': '01111001', '136': '01101001', '68': '01101000', '60': '01100101', '143': '01011101', '39': '01001001', '156': '01000101', '160': '01000100', '61': '01000000', '184': '00111101', '48': '00111001', '42': '00111000', '78': '00110110', '178': '00110001', '64': '00101000', '135': '00100001', '83': '00100000', '191': '00011110', '50': '00011001', '108': '00011000', '153': '00010101', '96': '00010100', '65': '00010011', '145': '00010001', '63': '00010000', '66': '00001010', '128': '00001000', '121': '00000111', '67': '00000101', '120': '00000001', '140': '00000000', '107': '1111110', '98': '1111101', '87': '1111100', '134': '1111011', '90': '1111001', '56': '1111000', '59': '1110111', '77': '1110110', '95': '1110010', '74': '1101011', '165': '1101010', '122': '1100111', '130': '1100101', '174': '1100100', '126': '0111110', '91': '0111101', '117': '0111001', '76': '0111000', '44': '0110101', '89': '0110011', '40': '0101111', '99': '0101001', '138': '0101000', '35': '0100101', '114': '0100011', '41': '0100001', '124': '0011111', '69': '0011101', '85': '0011010', '102': '0011001', '101': '0010111', '170': '0010110', '106': '0010101', '112': '0010011', '111': '0010010', '52': '0010001', '104': '0001110', '100': '0001011', '43': '0000001', '32': '111010', '109': '111000', '113': '110111', '72': '110110', '94': '110100', '36': '110001', '119': '110000', '34': '011101', '37': '011011', '115': '011000', '47': '010110', '81': '010101', '1': '010011', '38': '000011', '0': '10'}
